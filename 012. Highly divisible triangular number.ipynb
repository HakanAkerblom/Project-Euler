# %% [markdown]
# # Highly divisible triangular number
#
# ### Problem 12
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#  1: 1
#  3: 1,3
#  6: 1,2,3,6
# 10: 1,2,5,10
# 15: 1,3,5,15
# 21: 1,3,7,21
# 28: 1,2,4,7,14,28
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
# Generera lista med triangeltal
""" 
maximum = 10000
summa = 0
triangeltal = []
for i in range(1, maximum):
    summa = 0
    for j in range(1, i+1):
        summa += j
    triangeltal.append(summa)
# print(triangeltal)
print(max(triangeltal))

for i in triangeltal:
    delare = []
    for j in range(1, i+1):
        if i % j == 0:
            delare.append(j)
    # print(delare)
    if len(delare)>20:
        print(i)
        print(delare)
        break

 """

# %%
# Nytt försök med explicit formel
""" triangeltal = []
for i in range(1, 20):
    triangeltal.append(int((i**2+i)/2))
print(triangeltal) """
import math

for i in range(1, 3000):
    delare = []
    triangeltal = int((i**2 + i)/2)
    delare = 0
    for j in range(1, int(math.ceil(triangeltal))):
        if triangeltal % j == 0:
            delare += 2
    if delare>300:
        print(i)
        print(triangeltal)
        print(delare)
        break
# Out:
# 1224
# 749700
# 322
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [11], line 19
#      17 print(triangeltal)
#      18 print(delare)
# ---> 19 print(len(delare))
#      20 break
#
# TypeError: object of type 'int' has no len()

# %%
triangeltal = [int((i**2+i)/2) for i in range(1, 2000)]

# %%
import math
from time import time
t = time()
def divisors(n):
    number_of_factors = 0
    for i in range(1, int(math.ceil(math.sqrt(n)))+1):
        if n % i == 0:
            number_of_factors +=2
    return number_of_factors

x=1
for y in range(2,1000000):
    x += y
    if divisors(x) >= 500:
        print(x)
        break
tt = time()-t
print(tt)
# Out:
# 76576500
# 76576500
# 2.993842124938965
